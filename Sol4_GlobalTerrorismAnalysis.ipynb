# %% [markdown]
# <a href="https://colab.research.google.com/github/avneeshdubey99/GRIP-Internship/blob/main/Sol4_GlobalTerrorismAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Avneesh Dubey

# %% [markdown]
# #Task 4 - Global Terrorism Analysis

# %%
## Importing relevant libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
## Reading the csv file and encoding for unicode decode error

df = pd.read_csv('/content/drive/MyDrive/globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.describe # Strategical display of data
# Out:
# <bound method NDFrame.describe of              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       197000000001   1970       7     2  ...        0         0       0      NaN
# 1       197000000002   1970       0     0  ...        1         1       1      NaN
# 2       197001000001   1970       1     0  ...       -9         1       1      NaN
# 3       197001000002   1970       1     0  ...       -9         1       1      NaN
# 4       197001000003   1970       1     0  ...       -9         1       1      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 181686  201712310022   2017      12    31  ...        0         0       0      NaN
# 181687  201712310029   2017      12    31  ...       -9         1       1      NaN
# 181688  201712310030   2017      12    31  ...        0         0       0      NaN
# 181689  201712310031   2017      12    31  ...       -9         0      -9      NaN
# 181690  201712310032   2017      12    31  ...       -9         0      -9      NaN
#
# [181691 rows x 135 columns]>

# %%
df.info() # Detailed information about the imported 'df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.shape # Number of rows and columns
# Out:
# (181691, 135)

# %%
df.isnull().sum() # Checking for NA values
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
corr = df.corr()
corr  # Correlation pf the data
# Out:
#             eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999996  0.002706  ... -0.133252 -0.077852 -0.175605
# iyear      0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# imonth     0.002706  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# iday       0.018336  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended   0.091761  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  ...  0.040947  0.085055  0.064759
# INT_LOG   -0.143600 -0.143601 -0.002302  ...  0.996211  0.052537  0.891051
# INT_IDEO  -0.133252 -0.133253 -0.002034  ...  1.000000  0.082014  0.893811
# INT_MISC  -0.077852 -0.077847 -0.002554  ...  0.082014  1.000000  0.252193
# INT_ANY   -0.175605 -0.175596 -0.006336  ...  0.893811  0.252193  1.000000
#
# [77 rows x 77 columns]

# %% [markdown]
# ## DATA VISUALIZATION

# %%
df.hist(figsize=(50,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1484c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff144edd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1401080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff14212e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff13cf550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff13827b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff13b5a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1367c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1367cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff12dd198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff128e400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1244668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff12788d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff122bb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff11dcda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1191fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff11502b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1102518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1138780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff10eb9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff109dc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1050eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1012160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0fc43c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0ff7630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0faa898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0f5fb00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0f12d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0ec5fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0e86278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0e3c0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0e6f470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0e1f7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0dd2b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0d82ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0d412b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0d71630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0d239b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0cd5d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0c950f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0c47470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0c777f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0c29b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0bdaef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0b972b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0b4a630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0b789b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0b2dd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0aec0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0a9d470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0a4e7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff09ffb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0a32ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff09ef2b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff09a2630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff1404908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff12ddeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff11a6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff101b6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0e86898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0840d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0874fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0833278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff07e64e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0799748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff074d9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0700c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0734e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff06f2128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff06a7390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff065a5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff060d860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff05bfac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff05f3d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff05a8f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0567240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff051a4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff04cf710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0481978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff04b5be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0469e48>]],
#       dtype=object)

# %% [markdown]
# Checking which region has highest attacks and in which year.

# %%
## Graphical representation of terrorist activities by region
pd.crosstab(df.iyear,df.region_txt).plot(kind='area',figsize=(20,10))
plt.show()

# %% [markdown]
# Getting count of the attacks

# %%
plt.subplots(figsize=(20,10))
sns.countplot('iyear',data=df,palette='tab10',edgecolor=sns.color_palette("hls", 8))
plt.xticks(rotation=90)
plt.title('no of terror activities')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Highest number of attacks took place in the year 2014.

# %%
year = df.iyear.value_counts().to_dict()
rate = ((year[2017]-year[1970])/year[2017])*100
print('The number of attacks in the year 2017 is',year[2017],' and the number of attacks in the year 1970 is',year[1970])
# Out:
# The number of attacks in the year 2017 is 10900  and the number of attacks in the year 1970 is 651

# %% [markdown]
# From this we can say that the there has been a significant increase in the number of attacks from 1970 to 2017. Now, let's see the type of attack that has been used the most.

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['attacktype1_txt'],order=df['attacktype1_txt'].value_counts().index,palette='Paired')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# From this we can say that Bombing/Explosion have been used the most i.e.; more than 80000 times.

# %% [markdown]
# Now let's look at the type of places that have been targeted the most.

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['targtype1_txt'],order=df['targtype1_txt'].value_counts().index,palette='Paired')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Therefore, private citizens & property has been targeted the most i.e; more than 40000 time.

# %% [markdown]
# Now, let's look at the countries that are the most under attack.

# %%
fig,axes=plt.subplots(figsize=(20,10),nrows=1,ncols=1)
sns.barplot(x=df['country_txt'].value_counts()[:20].values,y=df['country_txt'].value_counts()[:20].index,palette='rocket')

# %% [markdown]
# Therefore the country that faces most number of terror attacks is Iraq i.e; about 25000.

# %% [markdown]
# Now, let's look at the regions that are the most under attack.

# %%
fig,axes=plt.subplots(figsize=(20,10),nrows=1,ncols=1)
sns.barplot(x=df['region_txt'].value_counts()[:20].values,y=df['region_txt'].value_counts()[:20].index,palette='mako')

# %% [markdown]
# Therefore, the region that is most under attack is Middle East and North Africa with more than 50000 attacks.

# %% [markdown]
# ## ANALYSIS ON CUSTOMIZED DATA

# %% [markdown]
# Terror attacks in a location/country in a particular year.

# %%
filterYear = df['iyear'] == 1970

# %%
filterData=df[filterYear]

# %%
filterData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 651 entries, 0 to 650
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 691.7+ KB

# %%
reqFilterData = filterData.loc[:,'city':'longitude']
reqFilterData=reqFilterData.dropna() #remove null values

# %%
reqFilterDataList=reqFilterData.values.tolist()

# %%
map=folium.Map(location=[0,30],tiles='CartoDB positron',zoom_start=2)

# %%
## Clustered marker
markerCluster= folium.plugins.MarkerCluster().add_to(map)
for point in range (0, len(reqFilterDataList)):
  folium.Marker(location=[reqFilterDataList[point][1],reqFilterDataList[point][2]],popup=reqFilterDataList[point][0]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Total number of people killed in terror attacks.

# %%
killData=df.loc[:,'nkill']
killData=killData.dropna() #remove null values

# %%
print('Number of people killed in terror attacks',int(sum(killData)))
# Out:
# Number of people killed in terror attacks 411868

# %% [markdown]
# Conclusion:
#
# *   Highest number of attacks took place in year 2014.
# *   Number of attacks in year 2017 is 10900 and number of attacks in year 1970 is 651.
# *   Bombing/Explosion have been used the most.
# *   Private citizens & property has been targeted the most.
# *   The country that faces most number of terror attacks is Iraq i.e; about 25000.
# *   The region that is most under attack is Middle East and North Africa with more than 50000 attacks.
# *   Number of people killed in terror attacks 411868.
